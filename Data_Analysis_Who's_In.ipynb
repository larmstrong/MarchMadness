# %% [markdown]
# <a href="https://colab.research.google.com/github/KaiserKyle/IST-718-Final-Project/blob/master/Data_Analysis_Who's_In.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Who's In
#
# This notebook handles creating models and making predictions of who is in.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  # 2D plotting
from matplotlib.cbook import boxplot_stats
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/KaiserKyle/IST-718-Final-Project/master/agg_team_stats.csv' ,low_memory=False)
sos = pd.read_csv('https://raw.githubusercontent.com/KaiserKyle/IST-718-Final-Project/master/rpi_sos.csv')

data = data.drop(['name', 'market', 'alias','conf_id','division_alias','conf_name'], axis=1)
data = data.merge(sos, how='left', left_on=['team_id', 'season'], right_on=['id', 'season'])
data['win_perc'] = data.Win / (data.Win + data.Loss)
data = data.drop(['Win','Loss'], axis = 1)
data.fillna(0, inplace=True)
conf_encode = pd.get_dummies(data['conf_alias'])
data = pd.concat([data, conf_encode], axis = 1)
data['Pt_Diff'] = data.points_game - data.opp_points_game
data['Rebound_Diff'] = data.rebounds - data.opp_rebounds
data['Turnover_Diff'] = data.turnovers - data.opp_turnovers
data.head()
# Out:
#    season                               team_id  ... Rebound_Diff  Turnover_Diff
# 0    2013  8ddbfca9-a931-4908-aa31-9fcd17624b5f  ...    -1.000000       2.750000
# 1    2013  11a617d5-af03-4cce-bc8a-51114d9e41fe  ...    -5.600000       0.400000
# 2    2013  d8217105-e9c2-4267-9538-3aaeea1ae167  ...   -11.166667       2.666667
# 3    2013  5016fe1a-9571-4d10-bf5b-b9c1b496bd57  ...   -14.500000       3.000000
# 4    2013  53aaac6a-796e-41a6-a04e-6ce74c5717f8  ...    -2.500000       6.500000
#
# [5 rows x 93 columns]

# %%
plt.rcParams['figure.figsize'] = [6, 6]
g = sns.boxplot(x="NCAA", y="points_game", data=data, color = "lightblue")
g.set(xlabel = "Is NCAA Tournament?", ylabel = "PPG")
g.set_title("Points Per Game")

plt.show()

# %%
at_large_data = data[data.Conference_Champ == False]
in_teams = data[data.Conference_Champ == True]

plt.rcParams['figure.figsize'] = [4, 15]
corr = at_large_data.corr()
corr = corr.loc[['NCAA']].transpose().sort_values(by = 'NCAA')
g = sns.heatmap(corr, 
            yticklabels=corr.index.values,
            annot = True,
            center = 0,
            vmin = -1,
            vmax = 1,
            cmap = 'coolwarm')

plt.title("Correlation with NCAA Berth For At-Large Teams")

plt.show()

# %%
train_data = at_large_data[(at_large_data['season'] == 2013) | (at_large_data['season'] == 2014) | (at_large_data['season'] == 2015)]
test_data = at_large_data[(at_large_data['season'] == 2016) | (at_large_data['season'] == 2017)]

y_test = test_data[['NCAA', 'season', 'team_id', 'market']]
y_train = train_data[['NCAA', 'season', 'team_id', 'market']]
X_test = test_data.drop(['NCAA', 'season', 'team_id', 'conf_alias', 'id', 'market'], axis=1)
X_train = train_data.drop(['NCAA', 'season', 'team_id', 'conf_alias', 'id', 'market'], axis=1)

X_train.head()
# Out:
#    points_game  field_goals_made  ...  Rebound_Diff  Turnover_Diff
# 0    71.451613          22.25000  ...     -1.000000       2.750000
# 1    69.741935          23.20000  ...     -5.600000       0.400000
# 2    69.393939          22.00000  ...    -11.166667       2.666667
# 4    65.281250          16.00000  ...     -2.500000       6.500000
# 5    65.156250          22.96875  ...     -2.500000      -2.093750
#
# [5 rows x 87 columns]

# %%
from sklearn import linear_model
clf = linear_model.SGDClassifier(loss="modified_huber", max_iter=1000)
clf.fit(X_train, y_train.NCAA)
print(clf.score(X_test, y_test.NCAA))

predictions = pd.DataFrame(clf.predict_proba(X_test))

predictions['Actual'] = y_test.NCAA.values
predictions['season'] = y_test.season.values
predictions['Team_Name'] = y_test.market.values
predictions['team_id'] = y_test.team_id.values
predictions.sort_values(by = 1, ascending = False, inplace = True)

pred_2016 = predictions[predictions['season'] == 2016]
pred_2017 = predictions[predictions['season'] == 2017]

in_2016 = pred_2016.head(36)
in_2017 = pred_2017.head(36)

print("2016 Top 36 at-large bids correct: ", in_2016.Actual.sum())
print("2017 Top 36 at-large bids correct: ", in_2017.Actual.sum())
# Out:
# 0.6755485893416928
# 2016 Top 36 at-large bids correct:  16
# 2017 Top 36 at-large bids correct:  17

# %%
from sklearn.svm import SVC
clf = SVC(probability = True)
clf.fit(X_train, y_train.NCAA)
print(clf.score(X_test, y_test.NCAA))

predictions = pd.DataFrame(clf.predict_proba(X_test))

predictions['Actual'] = y_test.NCAA.values
predictions['season'] = y_test.season.values
predictions['Team_Name'] = y_test.market.values
predictions['team_id'] = y_test.team_id.values
predictions.sort_values(by = 1, ascending = False, inplace = True)

pred_2016 = predictions[predictions['season'] == 2016]
pred_2017 = predictions[predictions['season'] == 2017]

in_2016 = pred_2016.head(36)
in_2017 = pred_2017.head(36)

print("2016 Top 36 at-large bids correct: ", in_2016.Actual.sum())
print("2017 Top 36 at-large bids correct: ", in_2017.Actual.sum())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.664576802507837
# 2016 Top 36 at-large bids correct:  32
# 2017 Top 36 at-large bids correct:  31

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=8)
neigh.fit(X_train, y_train.NCAA)
print(neigh.score(X_test, y_test.NCAA))

predictions = pd.DataFrame(neigh.predict_proba(X_test))

predictions['Actual'] = y_test.NCAA.values
predictions['season'] = y_test.season.values
predictions['Team_Name'] = y_test.market.values
predictions['team_id'] = y_test.team_id.values
predictions.sort_values(by = 1, ascending = False, inplace = True)

pred_2016 = predictions[predictions['season'] == 2016]
pred_2017 = predictions[predictions['season'] == 2017]

in_2016 = pred_2016.head(36)
in_2017 = pred_2017.head(36)

print("2016 Top 36 at-large bids correct: ", in_2016.Actual.sum())
print("2017 Top 36 at-large bids correct: ", in_2017.Actual.sum())
# Out:
# 0.8495297805642633
# 2016 Top 36 at-large bids correct:  36
# 2017 Top 36 at-large bids correct:  36

# %%
from numpy.random import seed
seed(2)

from sklearn.ensemble import RandomForestClassifier 

forest = RandomForestClassifier(n_estimators = 500)
forest.fit(X_train, y_train.NCAA)
print('Random Forest Score: ', forest.score(X_test, y_test.NCAA))

predictions = pd.DataFrame(forest.predict_proba(X_test))

predictions['Actual'] = y_test.NCAA.values
predictions['season'] = y_test.season.values
predictions['Team_Name'] = y_test.market.values
predictions['team_id'] = y_test.team_id.values
predictions.sort_values(by = 1, ascending = False, inplace = True)

pred_2016 = predictions[predictions['season'] == 2016]
pred_2017 = predictions[predictions['season'] == 2017]

in_2016 = pred_2016.head(36)
in_2017 = pred_2017.head(36)

print("2016 Top 36 at-large bids correct: ", in_2016.Actual.sum())
print("2017 Top 36 at-large bids correct: ", in_2017.Actual.sum())
# Out:
# Random Forest Score:  0.8495297805642633
# 2016 Top 36 at-large bids correct:  36
# 2017 Top 36 at-large bids correct:  35

# %%
conf_champ_2016 = in_teams[in_teams.season == 2016]
conf_champ_2016 = conf_champ_2016[['season', 'team_id', 'market']]
conf_champ_2016 = conf_champ_2016.rename(index=str, columns={"market": "Team_Name"})


full_predictions_2016 = pd.concat([conf_champ_2016, in_2016])
full_predictions_2016 = full_predictions_2016[['Team_Name','season','team_id']]

conf_champ_2017 = in_teams[in_teams.season == 2017]
conf_champ_2017 = conf_champ_2017[['season', 'team_id', 'market']]
conf_champ_2017 = conf_champ_2017.rename(index=str, columns={"market": "Team_Name"})


full_predictions_2017 = pd.concat([conf_champ_2017, in_2017])
full_predictions_2017 = full_predictions_2017[['Team_Name','season','team_id']]

full_predictions_2016.to_csv("predicted_2016.csv", index = False)
full_predictions_2017.to_csv("predicted_2017.csv", index = False)

from google.colab import files 
files.download('predicted_2016.csv')
files.download('predicted_2017.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(1)


from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.preprocessing import StandardScaler

print(X_train.shape)

def create_baseline():
	# create model
  model = Sequential()
  model.add(Dense(87, input_dim=87, kernel_initializer='normal', activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(50, kernel_initializer='normal', activation='softmax'))
  model.add(Dropout(0.5))
  model.add(Dense(30, kernel_initializer='normal', activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
	# Compile model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scale = scaler.transform(X_train)
X_test_scale = scaler.transform(X_test)

X_train_scale
# Out:
# (961, 87)
# Using TensorFlow backend.
# array([[ 0.23649742, -0.43131629,  0.77379028, ..., -0.09382445,
#         -0.01098564,  0.7755782 ],
#        [-0.06714247, -0.13877186,  0.56076152, ..., -0.20215186,
#         -0.78605474, -0.18487323],
#        [-0.12894681, -0.50830166, -0.40059903, ..., -0.53452004,
#         -1.72400068,  0.74151964],
#        ...,
#        [ 1.04429409,  0.77478793,  0.88849807, ..., -0.50907951,
#         -0.33112288,  0.06034841],
#        [ 0.55454674,  0.9474218 ,  0.69682184, ...,  0.30501737,
#          1.46460705,  0.03557855],
#        [ 1.22711832,  0.75969276,  0.69667579, ...,  1.46959492,
#          0.3012225 , -0.43249901]])

# %%
# %%time

model = create_baseline()

# FIT THE MODEL
history  = model.fit(X_train_scale, y_train.NCAA, validation_data=(X_test_scale, y_test.NCAA), epochs=500, batch_size=10000, verbose=2)

# EVALUATE THE MODEL
scores = model.evaluate(X_test_scale, y_test.NCAA, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0614 23:27:53.229221 140478485067648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0614 23:27:53.233651 140478485067648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0614 23:27:53.248872 140478485067648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0614 23:27:53.272301 140478485067648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0614 23:27:53.285470 140478485067648 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0614 23:27:53.383208 140478485067648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0614 23:27:53.411329 140478485067648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0614 23:27:53.420446 140478485067648 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 961 samples, validate on 638 samples
# Epoch 1/500
#  - 1s - loss: 0.6934 - acc: 0.4058 - val_loss: 0.6931 - val_acc: 0.6646
# Epoch 2/500
#  - 0s - loss: 0.6931 - acc: 0.4828 - val_loss: 0.6928 - val_acc: 0.6646
# Epoch 3/500
#  - 0s - loss: 0.6929 - acc: 0.5765 - val_loss: 0.6924 - val_acc: 0.6646
# Epoch 4/500
#  - 0s - loss: 0.6927 - acc: 0.6285 - val_loss: 0.6921 - val_acc: 0.6646
# Epoch 5/500
#  - 0s - loss: 0.6923 - acc: 0.6327 - val_loss: 0.6918 - val_acc: 0.6646
# Epoch 6/500
#  - 0s - loss: 0.6920 - acc: 0.6316 - val_loss: 0.6914 - val_acc: 0.6646
# Epoch 7/500
#  - 0s - loss: 0.6918 - acc: 0.6316 - val_loss: 0.6910 - val_acc: 0.6646
# Epoch 8/500
#  - 0s - loss: 0.6914 - acc: 0.6316 - val_loss: 0.6907 - val_acc: 0.6646
# Epoch 9/500
#  - 0s - loss: 0.6912 - acc: 0.6316 - val_loss: 0.6903 - val_acc: 0.6646
# Epoch 10/500
#  - 0s - loss: 0.6908 - acc: 0.6316 - val_loss: 0.6899 - val_acc: 0.6646
# Epoch 11/500
#  - 0s - loss: 0.6905 - acc: 0.6316 - val_loss: 0.6895 - val_acc: 0.6646
# Epoch 12/500
#  - 0s - loss: 0.6900 - acc: 0.6316 - val_loss: 0.6890 - val_acc: 0.6646
# Epoch 13/500
#  - 0s - loss: 0.6899 - acc: 0.6316 - val_loss: 0.6886 - val_acc: 0.6646
# Epoch 14/500
#  - 0s - loss: 0.6895 - acc: 0.6316 - val_loss: 0.6881 - val_acc: 0.6646
# Epoch 15/500
#  - 0s - loss: 0.6890 - acc: 0.6316 - val_loss: 0.6876 - val_acc: 0.6646
# Epoch 16/500
#  - 0s - loss: 0.6886 - acc: 0.6316 - val_loss: 0.6871 - val_acc: 0.6646
# Epoch 17/500
#  - 0s - loss: 0.6882 - acc: 0.6316 - val_loss: 0.6866 - val_acc: 0.6646
# Epoch 18/500
#  - 0s - loss: 0.6877 - acc: 0.6316 - val_loss: 0.6861 - val_acc: 0.6646
# Epoch 19/500
#  - 0s - loss: 0.6873 - acc: 0.6316 - val_loss: 0.6856 - val_acc: 0.6646
# Epoch 20/500
#  - 0s - loss: 0.6868 - acc: 0.6316 - val_loss: 0.6850 - val_acc: 0.6646
# Epoch 21/500
#  - 0s - loss: 0.6862 - acc: 0.6316 - val_loss: 0.6844 - val_acc: 0.6646
# Epoch 22/500
#  - 0s - loss: 0.6861 - acc: 0.6316 - val_loss: 0.6839 - val_acc: 0.6646
# Epoch 23/500
#  - 0s - loss: 0.6852 - acc: 0.6316 - val_loss: 0.6833 - val_acc: 0.6646
# Epoch 24/500
#  - 0s - loss: 0.6851 - acc: 0.6316 - val_loss: 0.6826 - val_acc: 0.6646
# Epoch 25/500
#  - 0s - loss: 0.6845 - acc: 0.6316 - val_loss: 0.6820 - val_acc: 0.6646
# Epoch 26/500
#  - 0s - loss: 0.6841 - acc: 0.6316 - val_loss: 0.6814 - val_acc: 0.6646
# Epoch 27/500
#  - 0s - loss: 0.6836 - acc: 0.6316 - val_loss: 0.6807 - val_acc: 0.6646
# Epoch 28/500
#  - 0s - loss: 0.6825 - acc: 0.6316 - val_loss: 0.6800 - val_acc: 0.6646
# Epoch 29/500
#  - 0s - loss: 0.6820 - acc: 0.6316 - val_loss: 0.6793 - val_acc: 0.6646
# Epoch 30/500
#  - 0s - loss: 0.6820 - acc: 0.6316 - val_loss: 0.6786 - val_acc: 0.6646
# Epoch 31/500
#  - 0s - loss: 0.6806 - acc: 0.6316 - val_loss: 0.6778 - val_acc: 0.6646
# Epoch 32/500
#  - 0s - loss: 0.6802 - acc: 0.6316 - val_loss: 0.6770 - val_acc: 0.6646
# Epoch 33/500
#  - 0s - loss: 0.6787 - acc: 0.6316 - val_loss: 0.6762 - val_acc: 0.6646
# Epoch 34/500
#  - 0s - loss: 0.6787 - acc: 0.6316 - val_loss: 0.6753 - val_acc: 0.6646
# Epoch 35/500
#  - 0s - loss: 0.6772 - acc: 0.6316 - val_loss: 0.6745 - val_acc: 0.6646
# Epoch 36/500
#  - 0s - loss: 0.6766 - acc: 0.6316 - val_loss: 0.6735 - val_acc: 0.6646
# Epoch 37/500
#  - 0s - loss: 0.6757 - acc: 0.6316 - val_loss: 0.6726 - val_acc: 0.6646
# Epoch 38/500
#  - 0s - loss: 0.6753 - acc: 0.6316 - val_loss: 0.6716 - val_acc: 0.6646
# Epoch 39/500
#  - 0s - loss: 0.6750 - acc: 0.6316 - val_loss: 0.6706 - val_acc: 0.6646
# Epoch 40/500
#  - 0s - loss: 0.6729 - acc: 0.6316 - val_loss: 0.6695 - val_acc: 0.6646
# Epoch 41/500
#  - 0s - loss: 0.6721 - acc: 0.6316 - val_loss: 0.6684 - val_acc: 0.6646
# Epoch 42/500
#  - 0s - loss: 0.6706 - acc: 0.6316 - val_loss: 0.6672 - val_acc: 0.6646
# Epoch 43/500
#  - 0s - loss: 0.6700 - acc: 0.6316 - val_loss: 0.6661 - val_acc: 0.6646
# Epoch 44/500
#  - 0s - loss: 0.6691 - acc: 0.6316 - val_loss: 0.6648 - val_acc: 0.6646
# Epoch 45/500
#  - 0s - loss: 0.6683 - acc: 0.6316 - val_loss: 0.6636 - val_acc: 0.6646
# Epoch 46/500
#  - 0s - loss: 0.6670 - acc: 0.6316 - val_loss: 0.6623 - val_acc: 0.6646
# Epoch 47/500
#  - 0s - loss: 0.6635 - acc: 0.6316 - val_loss: 0.6609 - val_acc: 0.6646
# Epoch 48/500
#  - 0s - loss: 0.6637 - acc: 0.6316 - val_loss: 0.6596 - val_acc: 0.6646
# Epoch 49/500
#  - 0s - loss: 0.6613 - acc: 0.6316 - val_loss: 0.6581 - val_acc: 0.6646
# Epoch 50/500
#  - 0s - loss: 0.6624 - acc: 0.6316 - val_loss: 0.6567 - val_acc: 0.6646
# Epoch 51/500
#  - 0s - loss: 0.6603 - acc: 0.6316 - val_loss: 0.6552 - val_acc: 0.6646
# Epoch 52/500
#  - 0s - loss: 0.6572 - acc: 0.6316 - val_loss: 0.6537 - val_acc: 0.6646
# Epoch 53/500
#  - 0s - loss: 0.6566 - acc: 0.6316 - val_loss: 0.6521 - val_acc: 0.6646
# Epoch 54/500
#  - 0s - loss: 0.6540 - acc: 0.6316 - val_loss: 0.6505 - val_acc: 0.6646
# Epoch 55/500
#  - 0s - loss: 0.6535 - acc: 0.6316 - val_loss: 0.6488 - val_acc: 0.6646
# Epoch 56/500
#  - 0s - loss: 0.6513 - acc: 0.6316 - val_loss: 0.6471 - val_acc: 0.6646
# Epoch 57/500
#  - 0s - loss: 0.6510 - acc: 0.6316 - val_loss: 0.6454 - val_acc: 0.6646
# Epoch 58/500
#  - 0s - loss: 0.6487 - acc: 0.6316 - val_loss: 0.6436 - val_acc: 0.6646
# Epoch 59/500
#  - 0s - loss: 0.6473 - acc: 0.6316 - val_loss: 0.6418 - val_acc: 0.6646
# Epoch 60/500
#  - 0s - loss: 0.6445 - acc: 0.6316 - val_loss: 0.6400 - val_acc: 0.6646
# Epoch 61/500
#  - 0s - loss: 0.6422 - acc: 0.6316 - val_loss: 0.6381 - val_acc: 0.6646
# Epoch 62/500
#  - 0s - loss: 0.6428 - acc: 0.6316 - val_loss: 0.6361 - val_acc: 0.6646
# Epoch 63/500
#  - 0s - loss: 0.6394 - acc: 0.6316 - val_loss: 0.6342 - val_acc: 0.6646
# Epoch 64/500
#  - 0s - loss: 0.6361 - acc: 0.6316 - val_loss: 0.6321 - val_acc: 0.6646
# Epoch 65/500
#  - 0s - loss: 0.6351 - acc: 0.6316 - val_loss: 0.6301 - val_acc: 0.6646
# Epoch 66/500
#  - 0s - loss: 0.6325 - acc: 0.6316 - val_loss: 0.6280 - val_acc: 0.6646
# Epoch 67/500
#  - 0s - loss: 0.6321 - acc: 0.6316 - val_loss: 0.6258 - val_acc: 0.6646
# Epoch 68/500
#  - 0s - loss: 0.6297 - acc: 0.6316 - val_loss: 0.6236 - val_acc: 0.6646
# Epoch 69/500
#  - 0s - loss: 0.6259 - acc: 0.6327 - val_loss: 0.6214 - val_acc: 0.6646
# Epoch 70/500
#  - 0s - loss: 0.6258 - acc: 0.6327 - val_loss: 0.6191 - val_acc: 0.6646
# Epoch 71/500
#  - 0s - loss: 0.6246 - acc: 0.6327 - val_loss: 0.6168 - val_acc: 0.6646
# Epoch 72/500
#  - 0s - loss: 0.6167 - acc: 0.6327 - val_loss: 0.6145 - val_acc: 0.6646
# Epoch 73/500
#  - 0s - loss: 0.6171 - acc: 0.6316 - val_loss: 0.6121 - val_acc: 0.6646
# Epoch 74/500
#  - 0s - loss: 0.6152 - acc: 0.6337 - val_loss: 0.6097 - val_acc: 0.6646
# Epoch 75/500
#  - 0s - loss: 0.6123 - acc: 0.6368 - val_loss: 0.6072 - val_acc: 0.6646
# Epoch 76/500
#  - 0s - loss: 0.6144 - acc: 0.6379 - val_loss: 0.6047 - val_acc: 0.6646
# Epoch 77/500
#  - 0s - loss: 0.6101 - acc: 0.6389 - val_loss: 0.6022 - val_acc: 0.6646
# Epoch 78/500
#  - 0s - loss: 0.6092 - acc: 0.6389 - val_loss: 0.5997 - val_acc: 0.6646
# Epoch 79/500
#  - 0s - loss: 0.6026 - acc: 0.6441 - val_loss: 0.5971 - val_acc: 0.6646
# Epoch 80/500
#  - 0s - loss: 0.6016 - acc: 0.6514 - val_loss: 0.5945 - val_acc: 0.6646
# Epoch 81/500
#  - 0s - loss: 0.6016 - acc: 0.6452 - val_loss: 0.5919 - val_acc: 0.6646
# Epoch 82/500
#  - 0s - loss: 0.6000 - acc: 0.6545 - val_loss: 0.5893 - val_acc: 0.6646
# Epoch 83/500
#  - 0s - loss: 0.5936 - acc: 0.6639 - val_loss: 0.5866 - val_acc: 0.6646
# Epoch 84/500
#  - 0s - loss: 0.5903 - acc: 0.6576 - val_loss: 0.5840 - val_acc: 0.6646
# Epoch 85/500
#  - 0s - loss: 0.5944 - acc: 0.6514 - val_loss: 0.5813 - val_acc: 0.6646
# Epoch 86/500
#  - 0s - loss: 0.5889 - acc: 0.6618 - val_loss: 0.5787 - val_acc: 0.6646
# Epoch 87/500
#  - 0s - loss: 0.5804 - acc: 0.6753 - val_loss: 0.5760 - val_acc: 0.6646
# Epoch 88/500
#  - 0s - loss: 0.5780 - acc: 0.6764 - val_loss: 0.5733 - val_acc: 0.6646
# Epoch 89/500
#  - 0s - loss: 0.5719 - acc: 0.6837 - val_loss: 0.5706 - val_acc: 0.6646
# Epoch 90/500
#  - 0s - loss: 0.5708 - acc: 0.6868 - val_loss: 0.5679 - val_acc: 0.6646
# Epoch 91/500
#  - 0s - loss: 0.5739 - acc: 0.6889 - val_loss: 0.5651 - val_acc: 0.6646
# Epoch 92/500
#  - 0s - loss: 0.5687 - acc: 0.6909 - val_loss: 0.5623 - val_acc: 0.6646
# Epoch 93/500
#  - 0s - loss: 0.5622 - acc: 0.7003 - val_loss: 0.5595 - val_acc: 0.6646
# Epoch 94/500
#  - 0s - loss: 0.5638 - acc: 0.7014 - val_loss: 0.5567 - val_acc: 0.6646
# Epoch 95/500
#  - 0s - loss: 0.5549 - acc: 0.7180 - val_loss: 0.5539 - val_acc: 0.6646
# Epoch 96/500
#  - 0s - loss: 0.5604 - acc: 0.7232 - val_loss: 0.5511 - val_acc: 0.7100
# Epoch 97/500
#  - 0s - loss: 0.5519 - acc: 0.7190 - val_loss: 0.5483 - val_acc: 0.7508
# Epoch 98/500
#  - 0s - loss: 0.5506 - acc: 0.7222 - val_loss: 0.5454 - val_acc: 0.7868
# Epoch 99/500
#  - 0s - loss: 0.5479 - acc: 0.7399 - val_loss: 0.5426 - val_acc: 0.8025
# Epoch 100/500
#  - 0s - loss: 0.5456 - acc: 0.7409 - val_loss: 0.5398 - val_acc: 0.8119
# Epoch 101/500
#  - 0s - loss: 0.5424 - acc: 0.7451 - val_loss: 0.5370 - val_acc: 0.8182
# Epoch 102/500
#  - 0s - loss: 0.5375 - acc: 0.7659 - val_loss: 0.5341 - val_acc: 0.8292
# Epoch 103/500
#  - 0s - loss: 0.5316 - acc: 0.7659 - val_loss: 0.5313 - val_acc: 0.8323
# Epoch 104/500
#  - 0s - loss: 0.5379 - acc: 0.7596 - val_loss: 0.5285 - val_acc: 0.8386
# Epoch 105/500
#  - 0s - loss: 0.5242 - acc: 0.7596 - val_loss: 0.5257 - val_acc: 0.8370
# Epoch 106/500
#  - 0s - loss: 0.5266 - acc: 0.7794 - val_loss: 0.5228 - val_acc: 0.8354
# Epoch 107/500
#  - 0s - loss: 0.5259 - acc: 0.7794 - val_loss: 0.5200 - val_acc: 0.8386
# Epoch 108/500
#  - 0s - loss: 0.5170 - acc: 0.7867 - val_loss: 0.5172 - val_acc: 0.8448
# Epoch 109/500
#  - 0s - loss: 0.5122 - acc: 0.7992 - val_loss: 0.5143 - val_acc: 0.8448
# Epoch 110/500
#  - 0s - loss: 0.5072 - acc: 0.7940 - val_loss: 0.5115 - val_acc: 0.8495
# Epoch 111/500
#  - 0s - loss: 0.5117 - acc: 0.7742 - val_loss: 0.5087 - val_acc: 0.8511
# Epoch 112/500
#  - 0s - loss: 0.5035 - acc: 0.8085 - val_loss: 0.5059 - val_acc: 0.8542
# Epoch 113/500
#  - 0s - loss: 0.5054 - acc: 0.7992 - val_loss: 0.5031 - val_acc: 0.8558
# Epoch 114/500
#  - 0s - loss: 0.4979 - acc: 0.8085 - val_loss: 0.5003 - val_acc: 0.8605
# Epoch 115/500
#  - 0s - loss: 0.4951 - acc: 0.8044 - val_loss: 0.4976 - val_acc: 0.8574
# Epoch 116/500
#  - 0s - loss: 0.4959 - acc: 0.7836 - val_loss: 0.4949 - val_acc: 0.8574
# Epoch 117/500
#  - 0s - loss: 0.4939 - acc: 0.8169 - val_loss: 0.4922 - val_acc: 0.8558
# Epoch 118/500
#  - 0s - loss: 0.4814 - acc: 0.8169 - val_loss: 0.4896 - val_acc: 0.8542
# Epoch 119/500
#  - 0s - loss: 0.4828 - acc: 0.8231 - val_loss: 0.4869 - val_acc: 0.8542
# Epoch 120/500
#  - 0s - loss: 0.4841 - acc: 0.8200 - val_loss: 0.4843 - val_acc: 0.8542
# Epoch 121/500
#  - 0s - loss: 0.4799 - acc: 0.8002 - val_loss: 0.4816 - val_acc: 0.8542
# Epoch 122/500
#  - 0s - loss: 0.4775 - acc: 0.8221 - val_loss: 0.4791 - val_acc: 0.8558
# Epoch 123/500
#  - 0s - loss: 0.4734 - acc: 0.8314 - val_loss: 0.4765 - val_acc: 0.8558
# Epoch 124/500
#  - 0s - loss: 0.4736 - acc: 0.8325 - val_loss: 0.4739 - val_acc: 0.8558
# Epoch 125/500
#  - 0s - loss: 0.4705 - acc: 0.8293 - val_loss: 0.4714 - val_acc: 0.8542
# Epoch 126/500
#  - 0s - loss: 0.4691 - acc: 0.8398 - val_loss: 0.4689 - val_acc: 0.8527
# Epoch 127/500
#  - 0s - loss: 0.4574 - acc: 0.8377 - val_loss: 0.4664 - val_acc: 0.8527
# Epoch 128/500
#  - 0s - loss: 0.4577 - acc: 0.8387 - val_loss: 0.4639 - val_acc: 0.8495
# Epoch 129/500
#  - 0s - loss: 0.4557 - acc: 0.8335 - val_loss: 0.4614 - val_acc: 0.8495
# Epoch 130/500
#  - 0s - loss: 0.4474 - acc: 0.8564 - val_loss: 0.4590 - val_acc: 0.8495
# Epoch 131/500
#  - 0s - loss: 0.4473 - acc: 0.8585 - val_loss: 0.4566 - val_acc: 0.8495
# Epoch 132/500
#  - 0s - loss: 0.4386 - acc: 0.8699 - val_loss: 0.4541 - val_acc: 0.8495
# Epoch 133/500
#  - 0s - loss: 0.4450 - acc: 0.8502 - val_loss: 0.4516 - val_acc: 0.8495
# Epoch 134/500
#  - 0s - loss: 0.4378 - acc: 0.8585 - val_loss: 0.4492 - val_acc: 0.8511
# Epoch 135/500
#  - 0s - loss: 0.4415 - acc: 0.8533 - val_loss: 0.4468 - val_acc: 0.8511
# Epoch 136/500
#  - 0s - loss: 0.4336 - acc: 0.8554 - val_loss: 0.4444 - val_acc: 0.8495
# Epoch 137/500
#  - 0s - loss: 0.4383 - acc: 0.8564 - val_loss: 0.4421 - val_acc: 0.8495
# Epoch 138/500
#  - 0s - loss: 0.4317 - acc: 0.8574 - val_loss: 0.4399 - val_acc: 0.8511
# Epoch 139/500
#  - 0s - loss: 0.4267 - acc: 0.8658 - val_loss: 0.4377 - val_acc: 0.8542
# Epoch 140/500
#  - 0s - loss: 0.4249 - acc: 0.8585 - val_loss: 0.4355 - val_acc: 0.8558
# Epoch 141/500
#  - 0s - loss: 0.4176 - acc: 0.8720 - val_loss: 0.4335 - val_acc: 0.8558
# Epoch 142/500
#  - 0s - loss: 0.4200 - acc: 0.8678 - val_loss: 0.4314 - val_acc: 0.8558
# Epoch 143/500
#  - 0s - loss: 0.4159 - acc: 0.8658 - val_loss: 0.4294 - val_acc: 0.8558
# Epoch 144/500
#  - 0s - loss: 0.4160 - acc: 0.8730 - val_loss: 0.4275 - val_acc: 0.8558
# Epoch 145/500
#  - 0s - loss: 0.4138 - acc: 0.8730 - val_loss: 0.4257 - val_acc: 0.8574
# Epoch 146/500
#  - 0s - loss: 0.4153 - acc: 0.8783 - val_loss: 0.4239 - val_acc: 0.8574
# Epoch 147/500
#  - 0s - loss: 0.4052 - acc: 0.8835 - val_loss: 0.4221 - val_acc: 0.8589
# Epoch 148/500
#  - 0s - loss: 0.3997 - acc: 0.8845 - val_loss: 0.4204 - val_acc: 0.8574
# Epoch 149/500
#  - 0s - loss: 0.4022 - acc: 0.8730 - val_loss: 0.4187 - val_acc: 0.8574
# Epoch 150/500
#  - 0s - loss: 0.3941 - acc: 0.8741 - val_loss: 0.4171 - val_acc: 0.8574
# Epoch 151/500
#  - 0s - loss: 0.3964 - acc: 0.8772 - val_loss: 0.4156 - val_acc: 0.8527
# Epoch 152/500
#  - 0s - loss: 0.3901 - acc: 0.8720 - val_loss: 0.4141 - val_acc: 0.8511
# Epoch 153/500
#  - 0s - loss: 0.3854 - acc: 0.8866 - val_loss: 0.4125 - val_acc: 0.8511
# Epoch 154/500
#  - 0s - loss: 0.3919 - acc: 0.8876 - val_loss: 0.4110 - val_acc: 0.8527
# Epoch 155/500
#  - 0s - loss: 0.3851 - acc: 0.8970 - val_loss: 0.4096 - val_acc: 0.8495
# Epoch 156/500
#  - 0s - loss: 0.3840 - acc: 0.8918 - val_loss: 0.4080 - val_acc: 0.8511
# Epoch 157/500
#  - 0s - loss: 0.3824 - acc: 0.8741 - val_loss: 0.4063 - val_acc: 0.8511
# Epoch 158/500
#  - 0s - loss: 0.3840 - acc: 0.8907 - val_loss: 0.4047 - val_acc: 0.8511
# Epoch 159/500
#  - 0s - loss: 0.3683 - acc: 0.8991 - val_loss: 0.4031 - val_acc: 0.8511
# Epoch 160/500
#  - 0s - loss: 0.3763 - acc: 0.8991 - val_loss: 0.4014 - val_acc: 0.8511
# Epoch 161/500
#  - 0s - loss: 0.3731 - acc: 0.9011 - val_loss: 0.3997 - val_acc: 0.8511
# Epoch 162/500
#  - 0s - loss: 0.3666 - acc: 0.8970 - val_loss: 0.3980 - val_acc: 0.8511
# Epoch 163/500
#  - 0s - loss: 0.3672 - acc: 0.8939 - val_loss: 0.3964 - val_acc: 0.8527
# Epoch 164/500
#  - 0s - loss: 0.3652 - acc: 0.8959 - val_loss: 0.3949 - val_acc: 0.8527
# Epoch 165/500
#  - 0s - loss: 0.3670 - acc: 0.8949 - val_loss: 0.3936 - val_acc: 0.8527
# Epoch 166/500
#  - 0s - loss: 0.3475 - acc: 0.9074 - val_loss: 0.3923 - val_acc: 0.8495
# Epoch 167/500
#  - 0s - loss: 0.3569 - acc: 0.8959 - val_loss: 0.3909 - val_acc: 0.8495
# Epoch 168/500
#  - 0s - loss: 0.3617 - acc: 0.8928 - val_loss: 0.3897 - val_acc: 0.8495
# Epoch 169/500
#  - 0s - loss: 0.3531 - acc: 0.8928 - val_loss: 0.3886 - val_acc: 0.8495
# Epoch 170/500
#  - 0s - loss: 0.3486 - acc: 0.9011 - val_loss: 0.3875 - val_acc: 0.8495
# Epoch 171/500
#  - 0s - loss: 0.3505 - acc: 0.8939 - val_loss: 0.3866 - val_acc: 0.8495
# Epoch 172/500
#  - 0s - loss: 0.3501 - acc: 0.9063 - val_loss: 0.3858 - val_acc: 0.8511
# Epoch 173/500
#  - 0s - loss: 0.3395 - acc: 0.9043 - val_loss: 0.3850 - val_acc: 0.8542
# Epoch 174/500
#  - 0s - loss: 0.3454 - acc: 0.9011 - val_loss: 0.3843 - val_acc: 0.8542
# Epoch 175/500
#  - 0s - loss: 0.3446 - acc: 0.9022 - val_loss: 0.3837 - val_acc: 0.8542
# Epoch 176/500
#  - 0s - loss: 0.3380 - acc: 0.9084 - val_loss: 0.3832 - val_acc: 0.8542
# Epoch 177/500
#  - 0s - loss: 0.3468 - acc: 0.8845 - val_loss: 0.3828 - val_acc: 0.8527
# Epoch 178/500
#  - 0s - loss: 0.3371 - acc: 0.9084 - val_loss: 0.3823 - val_acc: 0.8527
# Epoch 179/500
#  - 0s - loss: 0.3245 - acc: 0.9178 - val_loss: 0.3816 - val_acc: 0.8527
# Epoch 180/500
#  - 0s - loss: 0.3254 - acc: 0.9053 - val_loss: 0.3810 - val_acc: 0.8527
# Epoch 181/500
#  - 0s - loss: 0.3284 - acc: 0.9116 - val_loss: 0.3802 - val_acc: 0.8511
# Epoch 182/500
#  - 0s - loss: 0.3401 - acc: 0.9053 - val_loss: 0.3794 - val_acc: 0.8511
# Epoch 183/500
#  - 0s - loss: 0.3247 - acc: 0.9095 - val_loss: 0.3786 - val_acc: 0.8511
# Epoch 184/500
#  - 0s - loss: 0.3237 - acc: 0.9126 - val_loss: 0.3777 - val_acc: 0.8511
# Epoch 185/500
#  - 0s - loss: 0.3288 - acc: 0.9095 - val_loss: 0.3770 - val_acc: 0.8511
# Epoch 186/500
#  - 0s - loss: 0.3172 - acc: 0.9136 - val_loss: 0.3764 - val_acc: 0.8495
# Epoch 187/500
#  - 0s - loss: 0.3173 - acc: 0.9199 - val_loss: 0.3757 - val_acc: 0.8495
# Epoch 188/500
#  - 0s - loss: 0.3173 - acc: 0.9168 - val_loss: 0.3751 - val_acc: 0.8495
# Epoch 189/500
#  - 0s - loss: 0.3095 - acc: 0.9188 - val_loss: 0.3746 - val_acc: 0.8495
# Epoch 190/500
#  - 0s - loss: 0.3057 - acc: 0.9178 - val_loss: 0.3740 - val_acc: 0.8495
# Epoch 191/500
#  - 0s - loss: 0.3109 - acc: 0.9230 - val_loss: 0.3735 - val_acc: 0.8495
# Epoch 192/500
#  - 0s - loss: 0.3107 - acc: 0.9199 - val_loss: 0.3729 - val_acc: 0.8511
# Epoch 193/500
#  - 0s - loss: 0.3173 - acc: 0.9084 - val_loss: 0.3723 - val_acc: 0.8511
# Epoch 194/500
#  - 0s - loss: 0.3097 - acc: 0.9136 - val_loss: 0.3717 - val_acc: 0.8511
# Epoch 195/500
#  - 0s - loss: 0.3016 - acc: 0.9209 - val_loss: 0.3711 - val_acc: 0.8511
# Epoch 196/500
#  - 0s - loss: 0.3052 - acc: 0.9251 - val_loss: 0.3703 - val_acc: 0.8495
# Epoch 197/500
#  - 0s - loss: 0.3043 - acc: 0.9116 - val_loss: 0.3696 - val_acc: 0.8511
# Epoch 198/500
#  - 0s - loss: 0.3032 - acc: 0.9209 - val_loss: 0.3688 - val_acc: 0.8511
# Epoch 199/500
#  - 0s - loss: 0.2926 - acc: 0.9220 - val_loss: 0.3680 - val_acc: 0.8511
# Epoch 200/500
#  - 0s - loss: 0.2881 - acc: 0.9220 - val_loss: 0.3673 - val_acc: 0.8527
# Epoch 201/500
#  - 0s - loss: 0.2968 - acc: 0.9282 - val_loss: 0.3666 - val_acc: 0.8527
# Epoch 202/500
#  - 0s - loss: 0.2940 - acc: 0.9209 - val_loss: 0.3660 - val_acc: 0.8511
# Epoch 203/500
#  - 0s - loss: 0.2986 - acc: 0.9230 - val_loss: 0.3655 - val_acc: 0.8511
# Epoch 204/500
#  - 0s - loss: 0.2960 - acc: 0.9220 - val_loss: 0.3652 - val_acc: 0.8511
# Epoch 205/500
#  - 0s - loss: 0.2899 - acc: 0.9240 - val_loss: 0.3648 - val_acc: 0.8511
# Epoch 206/500
#  - 0s - loss: 0.2908 - acc: 0.9199 - val_loss: 0.3645 - val_acc: 0.8511
# Epoch 207/500
#  - 0s - loss: 0.2811 - acc: 0.9251 - val_loss: 0.3642 - val_acc: 0.8511
# Epoch 208/500
#  - 0s - loss: 0.2880 - acc: 0.9240 - val_loss: 0.3639 - val_acc: 0.8511
# Epoch 209/500
#  - 0s - loss: 0.2788 - acc: 0.9230 - val_loss: 0.3636 - val_acc: 0.8480
# Epoch 210/500
#  - 0s - loss: 0.2776 - acc: 0.9209 - val_loss: 0.3632 - val_acc: 0.8480
# Epoch 211/500
#  - 0s - loss: 0.2897 - acc: 0.9157 - val_loss: 0.3630 - val_acc: 0.8495
# Epoch 212/500
#  - 0s - loss: 0.2774 - acc: 0.9282 - val_loss: 0.3627 - val_acc: 0.8495
# Epoch 213/500
#  - 0s - loss: 0.2741 - acc: 0.9303 - val_loss: 0.3624 - val_acc: 0.8495
# Epoch 214/500
#  - 0s - loss: 0.2758 - acc: 0.9240 - val_loss: 0.3621 - val_acc: 0.8511
# Epoch 215/500
#  - 0s - loss: 0.2705 - acc: 0.9240 - val_loss: 0.3619 - val_acc: 0.8511
# Epoch 216/500
#  - 0s - loss: 0.2712 - acc: 0.9251 - val_loss: 0.3617 - val_acc: 0.8511
# Epoch 217/500
#  - 0s - loss: 0.2670 - acc: 0.9272 - val_loss: 0.3615 - val_acc: 0.8511
# Epoch 218/500
#  - 0s - loss: 0.2688 - acc: 0.9282 - val_loss: 0.3613 - val_acc: 0.8511
# Epoch 219/500
#  - 0s - loss: 0.2615 - acc: 0.9355 - val_loss: 0.3610 - val_acc: 0.8511
# Epoch 220/500
#  - 0s - loss: 0.2715 - acc: 0.9386 - val_loss: 0.3607 - val_acc: 0.8511
# Epoch 221/500
#  - 0s - loss: 0.2591 - acc: 0.9386 - val_loss: 0.3605 - val_acc: 0.8511
# Epoch 222/500
#  - 0s - loss: 0.2515 - acc: 0.9344 - val_loss: 0.3603 - val_acc: 0.8511
# Epoch 223/500
#  - 0s - loss: 0.2558 - acc: 0.9407 - val_loss: 0.3599 - val_acc: 0.8511
# Epoch 224/500
#  - 0s - loss: 0.2608 - acc: 0.9365 - val_loss: 0.3596 - val_acc: 0.8527
# Epoch 225/500
#  - 0s - loss: 0.2721 - acc: 0.9261 - val_loss: 0.3592 - val_acc: 0.8558
# Epoch 226/500
#  - 0s - loss: 0.2656 - acc: 0.9240 - val_loss: 0.3589 - val_acc: 0.8558
# Epoch 227/500
#  - 0s - loss: 0.2506 - acc: 0.9251 - val_loss: 0.3588 - val_acc: 0.8558
# Epoch 228/500
#  - 0s - loss: 0.2539 - acc: 0.9272 - val_loss: 0.3587 - val_acc: 0.8558
# Epoch 229/500
#  - 0s - loss: 0.2503 - acc: 0.9355 - val_loss: 0.3586 - val_acc: 0.8574
# Epoch 230/500
#  - 0s - loss: 0.2450 - acc: 0.9396 - val_loss: 0.3585 - val_acc: 0.8574
# Epoch 231/500
#  - 0s - loss: 0.2507 - acc: 0.9344 - val_loss: 0.3584 - val_acc: 0.8574
# Epoch 232/500
#  - 0s - loss: 0.2609 - acc: 0.9365 - val_loss: 0.3583 - val_acc: 0.8574
# Epoch 233/500
#  - 0s - loss: 0.2548 - acc: 0.9282 - val_loss: 0.3581 - val_acc: 0.8574
# Epoch 234/500
#  - 0s - loss: 0.2382 - acc: 0.9376 - val_loss: 0.3582 - val_acc: 0.8558
# Epoch 235/500
#  - 0s - loss: 0.2397 - acc: 0.9428 - val_loss: 0.3584 - val_acc: 0.8558
# Epoch 236/500
#  - 0s - loss: 0.2452 - acc: 0.9355 - val_loss: 0.3583 - val_acc: 0.8558
# Epoch 237/500
#  - 0s - loss: 0.2354 - acc: 0.9417 - val_loss: 0.3583 - val_acc: 0.8558
# Epoch 238/500
#  - 0s - loss: 0.2406 - acc: 0.9417 - val_loss: 0.3583 - val_acc: 0.8542
# Epoch 239/500
#  - 0s - loss: 0.2409 - acc: 0.9417 - val_loss: 0.3583 - val_acc: 0.8542
# Epoch 240/500
#  - 0s - loss: 0.2484 - acc: 0.9355 - val_loss: 0.3583 - val_acc: 0.8542
# Epoch 241/500
#  - 0s - loss: 0.2330 - acc: 0.9386 - val_loss: 0.3584 - val_acc: 0.8542
# Epoch 242/500
#  - 0s - loss: 0.2358 - acc: 0.9417 - val_loss: 0.3585 - val_acc: 0.8527
# Epoch 243/500
#  - 0s - loss: 0.2305 - acc: 0.9438 - val_loss: 0.3585 - val_acc: 0.8527
# Epoch 244/500
#  - 0s - loss: 0.2333 - acc: 0.9396 - val_loss: 0.3586 - val_acc: 0.8527
# Epoch 245/500
#  - 0s - loss: 0.2385 - acc: 0.9448 - val_loss: 0.3589 - val_acc: 0.8527
# Epoch 246/500
#  - 0s - loss: 0.2320 - acc: 0.9365 - val_loss: 0.3590 - val_acc: 0.8527
# Epoch 247/500
#  - 0s - loss: 0.2440 - acc: 0.9355 - val_loss: 0.3591 - val_acc: 0.8527
# Epoch 248/500
#  - 0s - loss: 0.2322 - acc: 0.9428 - val_loss: 0.3590 - val_acc: 0.8527
# Epoch 249/500
#  - 0s - loss: 0.2463 - acc: 0.9344 - val_loss: 0.3591 - val_acc: 0.8527
# Epoch 250/500
#  - 0s - loss: 0.2341 - acc: 0.9417 - val_loss: 0.3592 - val_acc: 0.8527
# Epoch 251/500
#  - 0s - loss: 0.2410 - acc: 0.9355 - val_loss: 0.3594 - val_acc: 0.8527
# Epoch 252/500
#  - 0s - loss: 0.2347 - acc: 0.9407 - val_loss: 0.3595 - val_acc: 0.8527
# Epoch 253/500
#  - 0s - loss: 0.2293 - acc: 0.9396 - val_loss: 0.3594 - val_acc: 0.8527
# Epoch 254/500
#  - 0s - loss: 0.2190 - acc: 0.9469 - val_loss: 0.3592 - val_acc: 0.8527
# Epoch 255/500
#  - 0s - loss: 0.2332 - acc: 0.9365 - val_loss: 0.3590 - val_acc: 0.8527
# Epoch 256/500
#  - 0s - loss: 0.2328 - acc: 0.9324 - val_loss: 0.3589 - val_acc: 0.8527
# Epoch 257/500
#  - 0s - loss: 0.2163 - acc: 0.9386 - val_loss: 0.3587 - val_acc: 0.8527
# Epoch 258/500
#  - 0s - loss: 0.2191 - acc: 0.9459 - val_loss: 0.3585 - val_acc: 0.8527
# Epoch 259/500
#  - 0s - loss: 0.2265 - acc: 0.9459 - val_loss: 0.3582 - val_acc: 0.8542
# Epoch 260/500
#  - 0s - loss: 0.2262 - acc: 0.9376 - val_loss: 0.3580 - val_acc: 0.8542
# Epoch 261/500
#  - 0s - loss: 0.2106 - acc: 0.9480 - val_loss: 0.3576 - val_acc: 0.8542
# Epoch 262/500
#  - 0s - loss: 0.2145 - acc: 0.9490 - val_loss: 0.3573 - val_acc: 0.8542
# Epoch 263/500
#  - 0s - loss: 0.2201 - acc: 0.9355 - val_loss: 0.3570 - val_acc: 0.8542
# Epoch 264/500
#  - 0s - loss: 0.2229 - acc: 0.9448 - val_loss: 0.3567 - val_acc: 0.8542
# Epoch 265/500
#  - 0s - loss: 0.2236 - acc: 0.9386 - val_loss: 0.3567 - val_acc: 0.8542
# Epoch 266/500
#  - 0s - loss: 0.2230 - acc: 0.9501 - val_loss: 0.3565 - val_acc: 0.8527
# Epoch 267/500
#  - 0s - loss: 0.2101 - acc: 0.9501 - val_loss: 0.3564 - val_acc: 0.8527
# Epoch 268/500
#  - 0s - loss: 0.2240 - acc: 0.9396 - val_loss: 0.3563 - val_acc: 0.8542
# Epoch 269/500
#  - 0s - loss: 0.2208 - acc: 0.9376 - val_loss: 0.3562 - val_acc: 0.8542
# Epoch 270/500
#  - 0s - loss: 0.2313 - acc: 0.9355 - val_loss: 0.3562 - val_acc: 0.8542
# Epoch 271/500
#  - 0s - loss: 0.2176 - acc: 0.9438 - val_loss: 0.3565 - val_acc: 0.8558
# Epoch 272/500
#  - 0s - loss: 0.2219 - acc: 0.9417 - val_loss: 0.3569 - val_acc: 0.8558
# Epoch 273/500
#  - 0s - loss: 0.2202 - acc: 0.9428 - val_loss: 0.3574 - val_acc: 0.8574
# Epoch 274/500
#  - 0s - loss: 0.1970 - acc: 0.9542 - val_loss: 0.3577 - val_acc: 0.8589
# Epoch 275/500
#  - 0s - loss: 0.2240 - acc: 0.9407 - val_loss: 0.3577 - val_acc: 0.8589
# Epoch 276/500
#  - 0s - loss: 0.2075 - acc: 0.9480 - val_loss: 0.3576 - val_acc: 0.8589
# Epoch 277/500
#  - 0s - loss: 0.2145 - acc: 0.9376 - val_loss: 0.3575 - val_acc: 0.8589
# Epoch 278/500
#  - 0s - loss: 0.2083 - acc: 0.9448 - val_loss: 0.3577 - val_acc: 0.8574
# Epoch 279/500
#  - 0s - loss: 0.2003 - acc: 0.9521 - val_loss: 0.3580 - val_acc: 0.8558
# Epoch 280/500
#  - 0s - loss: 0.2159 - acc: 0.9469 - val_loss: 0.3581 - val_acc: 0.8558
# Epoch 281/500
#  - 0s - loss: 0.2037 - acc: 0.9438 - val_loss: 0.3583 - val_acc: 0.8558
# Epoch 282/500
#  - 0s - loss: 0.1970 - acc: 0.9490 - val_loss: 0.3585 - val_acc: 0.8574
# Epoch 283/500
#  - 0s - loss: 0.2069 - acc: 0.9521 - val_loss: 0.3585 - val_acc: 0.8574
# Epoch 284/500
#  - 0s - loss: 0.2114 - acc: 0.9521 - val_loss: 0.3584 - val_acc: 0.8589
# Epoch 285/500
#  - 0s - loss: 0.1990 - acc: 0.9480 - val_loss: 0.3584 - val_acc: 0.8589
# Epoch 286/500
#  - 0s - loss: 0.1988 - acc: 0.9501 - val_loss: 0.3583 - val_acc: 0.8589
# Epoch 287/500
#  - 0s - loss: 0.2108 - acc: 0.9428 - val_loss: 0.3584 - val_acc: 0.8589
# Epoch 288/500
#  - 0s - loss: 0.2031 - acc: 0.9459 - val_loss: 0.3585 - val_acc: 0.8589
# Epoch 289/500
#  - 0s - loss: 0.2110 - acc: 0.9511 - val_loss: 0.3586 - val_acc: 0.8589
# Epoch 290/500
#  - 0s - loss: 0.2018 - acc: 0.9511 - val_loss: 0.3589 - val_acc: 0.8589
# Epoch 291/500
#  - 0s - loss: 0.1961 - acc: 0.9407 - val_loss: 0.3593 - val_acc: 0.8589
# Epoch 292/500
#  - 0s - loss: 0.2066 - acc: 0.9469 - val_loss: 0.3596 - val_acc: 0.8589
# Epoch 293/500
#  - 0s - loss: 0.1972 - acc: 0.9563 - val_loss: 0.3599 - val_acc: 0.8589
# Epoch 294/500
#  - 0s - loss: 0.1962 - acc: 0.9532 - val_loss: 0.3601 - val_acc: 0.8574
# Epoch 295/500
#  - 0s - loss: 0.2029 - acc: 0.9490 - val_loss: 0.3605 - val_acc: 0.8574
# Epoch 296/500
#  - 0s - loss: 0.1992 - acc: 0.9469 - val_loss: 0.3609 - val_acc: 0.8574
# Epoch 297/500
#  - 0s - loss: 0.1974 - acc: 0.9584 - val_loss: 0.3612 - val_acc: 0.8574
# Epoch 298/500
#  - 0s - loss: 0.1997 - acc: 0.9511 - val_loss: 0.3615 - val_acc: 0.8574
# Epoch 299/500
#  - 0s - loss: 0.1895 - acc: 0.9532 - val_loss: 0.3615 - val_acc: 0.8558
# Epoch 300/500
#  - 0s - loss: 0.1884 - acc: 0.9563 - val_loss: 0.3615 - val_acc: 0.8542
# Epoch 301/500
#  - 0s - loss: 0.2045 - acc: 0.9490 - val_loss: 0.3614 - val_acc: 0.8542
# Epoch 302/500
#  - 0s - loss: 0.1979 - acc: 0.9553 - val_loss: 0.3612 - val_acc: 0.8574
# Epoch 303/500
#  - 0s - loss: 0.1906 - acc: 0.9469 - val_loss: 0.3609 - val_acc: 0.8589
# Epoch 304/500
#  - 0s - loss: 0.1899 - acc: 0.9521 - val_loss: 0.3608 - val_acc: 0.8605
# Epoch 305/500
#  - 0s - loss: 0.1777 - acc: 0.9511 - val_loss: 0.3607 - val_acc: 0.8605
# Epoch 306/500
#  - 0s - loss: 0.1769 - acc: 0.9657 - val_loss: 0.3605 - val_acc: 0.8605
# Epoch 307/500
#  - 0s - loss: 0.1808 - acc: 0.9615 - val_loss: 0.3603 - val_acc: 0.8636
# Epoch 308/500
#  - 0s - loss: 0.1890 - acc: 0.9553 - val_loss: 0.3602 - val_acc: 0.8636
# Epoch 309/500
#  - 0s - loss: 0.1756 - acc: 0.9584 - val_loss: 0.3601 - val_acc: 0.8636
# Epoch 310/500
#  - 0s - loss: 0.1816 - acc: 0.9553 - val_loss: 0.3602 - val_acc: 0.8668
# Epoch 311/500
#  - 0s - loss: 0.1819 - acc: 0.9553 - val_loss: 0.3602 - val_acc: 0.8668
# Epoch 312/500
#  - 0s - loss: 0.1921 - acc: 0.9573 - val_loss: 0.3604 - val_acc: 0.8668
# Epoch 313/500
#  - 0s - loss: 0.1838 - acc: 0.9521 - val_loss: 0.3607 - val_acc: 0.8668
# Epoch 314/500
#  - 0s - loss: 0.1832 - acc: 0.9448 - val_loss: 0.3611 - val_acc: 0.8668
# Epoch 315/500
#  - 0s - loss: 0.1865 - acc: 0.9553 - val_loss: 0.3615 - val_acc: 0.8668
# Epoch 316/500
#  - 0s - loss: 0.1907 - acc: 0.9532 - val_loss: 0.3620 - val_acc: 0.8668
# Epoch 317/500
#  - 0s - loss: 0.1715 - acc: 0.9584 - val_loss: 0.3624 - val_acc: 0.8668
# Epoch 318/500
#  - 0s - loss: 0.1779 - acc: 0.9573 - val_loss: 0.3625 - val_acc: 0.8668
# Epoch 319/500
#  - 0s - loss: 0.1830 - acc: 0.9563 - val_loss: 0.3627 - val_acc: 0.8668
# Epoch 320/500
#  - 0s - loss: 0.1802 - acc: 0.9501 - val_loss: 0.3629 - val_acc: 0.8636
# Epoch 321/500
#  - 0s - loss: 0.1758 - acc: 0.9563 - val_loss: 0.3631 - val_acc: 0.8636
# Epoch 322/500
#  - 0s - loss: 0.1753 - acc: 0.9625 - val_loss: 0.3632 - val_acc: 0.8621
# Epoch 323/500
#  - 0s - loss: 0.1837 - acc: 0.9532 - val_loss: 0.3635 - val_acc: 0.8636
# Epoch 324/500
#  - 0s - loss: 0.1908 - acc: 0.9521 - val_loss: 0.3636 - val_acc: 0.8636
# Epoch 325/500
#  - 0s - loss: 0.1820 - acc: 0.9459 - val_loss: 0.3639 - val_acc: 0.8652
# Epoch 326/500
#  - 0s - loss: 0.1700 - acc: 0.9573 - val_loss: 0.3640 - val_acc: 0.8652
# Epoch 327/500
#  - 0s - loss: 0.1808 - acc: 0.9532 - val_loss: 0.3641 - val_acc: 0.8636
# Epoch 328/500
#  - 0s - loss: 0.1807 - acc: 0.9573 - val_loss: 0.3642 - val_acc: 0.8636
# Epoch 329/500
#  - 0s - loss: 0.1783 - acc: 0.9532 - val_loss: 0.3642 - val_acc: 0.8621
# Epoch 330/500
#  - 0s - loss: 0.1687 - acc: 0.9563 - val_loss: 0.3643 - val_acc: 0.8621
# Epoch 331/500
#  - 0s - loss: 0.1688 - acc: 0.9646 - val_loss: 0.3644 - val_acc: 0.8621
# Epoch 332/500
#  - 0s - loss: 0.1684 - acc: 0.9594 - val_loss: 0.3647 - val_acc: 0.8621
# Epoch 333/500
#  - 0s - loss: 0.1679 - acc: 0.9605 - val_loss: 0.3647 - val_acc: 0.8621
# Epoch 334/500
#  - 0s - loss: 0.1734 - acc: 0.9625 - val_loss: 0.3648 - val_acc: 0.8652
# Epoch 335/500
#  - 0s - loss: 0.1688 - acc: 0.9594 - val_loss: 0.3650 - val_acc: 0.8683
# Epoch 336/500
#  - 0s - loss: 0.1739 - acc: 0.9511 - val_loss: 0.3655 - val_acc: 0.8668
# Epoch 337/500
#  - 0s - loss: 0.1599 - acc: 0.9584 - val_loss: 0.3662 - val_acc: 0.8683
# Epoch 338/500
#  - 0s - loss: 0.1638 - acc: 0.9573 - val_loss: 0.3673 - val_acc: 0.8668
# Epoch 339/500
#  - 0s - loss: 0.1897 - acc: 0.9459 - val_loss: 0.3680 - val_acc: 0.8668
# Epoch 340/500
#  - 0s - loss: 0.1652 - acc: 0.9553 - val_loss: 0.3686 - val_acc: 0.8668
# Epoch 341/500
#  - 0s - loss: 0.1577 - acc: 0.9542 - val_loss: 0.3688 - val_acc: 0.8668
# Epoch 342/500
#  - 0s - loss: 0.1710 - acc: 0.9521 - val_loss: 0.3691 - val_acc: 0.8668
# Epoch 343/500
#  - 0s - loss: 0.1688 - acc: 0.9584 - val_loss: 0.3692 - val_acc: 0.8668
# Epoch 344/500
#  - 0s - loss: 0.1667 - acc: 0.9532 - val_loss: 0.3693 - val_acc: 0.8668
# Epoch 345/500
#  - 0s - loss: 0.1747 - acc: 0.9532 - val_loss: 0.3693 - val_acc: 0.8668
# Epoch 346/500
#  - 0s - loss: 0.1703 - acc: 0.9584 - val_loss: 0.3693 - val_acc: 0.8668
# Epoch 347/500
#  - 0s - loss: 0.1651 - acc: 0.9605 - val_loss: 0.3694 - val_acc: 0.8668
# Epoch 348/500
#  - 0s - loss: 0.1662 - acc: 0.9553 - val_loss: 0.3695 - val_acc: 0.8668
# Epoch 349/500
#  - 0s - loss: 0.1673 - acc: 0.9532 - val_loss: 0.3697 - val_acc: 0.8668
# Epoch 350/500
#  - 0s - loss: 0.1760 - acc: 0.9584 - val_loss: 0.3702 - val_acc: 0.8668
# Epoch 351/500
#  - 0s - loss: 0.1609 - acc: 0.9584 - val_loss: 0.3709 - val_acc: 0.8652
# Epoch 352/500
#  - 0s - loss: 0.1694 - acc: 0.9573 - val_loss: 0.3718 - val_acc: 0.8652
# Epoch 353/500
#  - 0s - loss: 0.1531 - acc: 0.9667 - val_loss: 0.3726 - val_acc: 0.8652
# Epoch 354/500
#  - 0s - loss: 0.1619 - acc: 0.9615 - val_loss: 0.3732 - val_acc: 0.8652
# Epoch 355/500
#  - 0s - loss: 0.1542 - acc: 0.9615 - val_loss: 0.3737 - val_acc: 0.8652
# Epoch 356/500
#  - 0s - loss: 0.1494 - acc: 0.9657 - val_loss: 0.3740 - val_acc: 0.8652
# Epoch 357/500
#  - 0s - loss: 0.1558 - acc: 0.9563 - val_loss: 0.3743 - val_acc: 0.8652
# Epoch 358/500
#  - 0s - loss: 0.1688 - acc: 0.9594 - val_loss: 0.3743 - val_acc: 0.8652
# Epoch 359/500
#  - 0s - loss: 0.1609 - acc: 0.9563 - val_loss: 0.3745 - val_acc: 0.8652
# Epoch 360/500
#  - 0s - loss: 0.1682 - acc: 0.9584 - val_loss: 0.3750 - val_acc: 0.8652
# Epoch 361/500
#  - 0s - loss: 0.1550 - acc: 0.9573 - val_loss: 0.3755 - val_acc: 0.8652
# Epoch 362/500
#  - 0s - loss: 0.1536 - acc: 0.9646 - val_loss: 0.3755 - val_acc: 0.8636
# Epoch 363/500
#  - 0s - loss: 0.1551 - acc: 0.9636 - val_loss: 0.3758 - val_acc: 0.8652
# Epoch 364/500
#  - 0s - loss: 0.1650 - acc: 0.9615 - val_loss: 0.3758 - val_acc: 0.8652
# Epoch 365/500
#  - 0s - loss: 0.1618 - acc: 0.9657 - val_loss: 0.3761 - val_acc: 0.8668
# Epoch 366/500
#  - 0s - loss: 0.1481 - acc: 0.9677 - val_loss: 0.3764 - val_acc: 0.8683
# Epoch 367/500
#  - 0s - loss: 0.1598 - acc: 0.9625 - val_loss: 0.3768 - val_acc: 0.8699
# Epoch 368/500
#  - 0s - loss: 0.1506 - acc: 0.9646 - val_loss: 0.3771 - val_acc: 0.8715
# Epoch 369/500
#  - 0s - loss: 0.1588 - acc: 0.9625 - val_loss: 0.3774 - val_acc: 0.8699
# Epoch 370/500
#  - 0s - loss: 0.1473 - acc: 0.9667 - val_loss: 0.3778 - val_acc: 0.8715
# Epoch 371/500
#  - 0s - loss: 0.1613 - acc: 0.9605 - val_loss: 0.3783 - val_acc: 0.8715
# Epoch 372/500
#  - 0s - loss: 0.1601 - acc: 0.9594 - val_loss: 0.3786 - val_acc: 0.8715
# Epoch 373/500
#  - 0s - loss: 0.1485 - acc: 0.9615 - val_loss: 0.3789 - val_acc: 0.8715
# Epoch 374/500
#  - 0s - loss: 0.1510 - acc: 0.9657 - val_loss: 0.3791 - val_acc: 0.8715
# Epoch 375/500
#  - 0s - loss: 0.1378 - acc: 0.9667 - val_loss: 0.3794 - val_acc: 0.8730
# Epoch 376/500
#  - 0s - loss: 0.1571 - acc: 0.9594 - val_loss: 0.3797 - val_acc: 0.8715
# Epoch 377/500
#  - 0s - loss: 0.1382 - acc: 0.9677 - val_loss: 0.3795 - val_acc: 0.8715
# Epoch 378/500
#  - 0s - loss: 0.1422 - acc: 0.9625 - val_loss: 0.3794 - val_acc: 0.8730
# Epoch 379/500
#  - 0s - loss: 0.1516 - acc: 0.9698 - val_loss: 0.3795 - val_acc: 0.8730
# Epoch 380/500
#  - 0s - loss: 0.1649 - acc: 0.9532 - val_loss: 0.3797 - val_acc: 0.8730
# Epoch 381/500
#  - 0s - loss: 0.1573 - acc: 0.9657 - val_loss: 0.3799 - val_acc: 0.8730
# Epoch 382/500
#  - 0s - loss: 0.1409 - acc: 0.9657 - val_loss: 0.3803 - val_acc: 0.8730
# Epoch 383/500
#  - 0s - loss: 0.1506 - acc: 0.9667 - val_loss: 0.3807 - val_acc: 0.8730
# Epoch 384/500
#  - 0s - loss: 0.1494 - acc: 0.9573 - val_loss: 0.3810 - val_acc: 0.8730
# Epoch 385/500
#  - 0s - loss: 0.1605 - acc: 0.9625 - val_loss: 0.3815 - val_acc: 0.8730
# Epoch 386/500
#  - 0s - loss: 0.1536 - acc: 0.9625 - val_loss: 0.3817 - val_acc: 0.8730
# Epoch 387/500
#  - 0s - loss: 0.1406 - acc: 0.9657 - val_loss: 0.3820 - val_acc: 0.8746
# Epoch 388/500
#  - 0s - loss: 0.1536 - acc: 0.9573 - val_loss: 0.3821 - val_acc: 0.8746
# Epoch 389/500
#  - 0s - loss: 0.1466 - acc: 0.9657 - val_loss: 0.3823 - val_acc: 0.8746
# Epoch 390/500
#  - 0s - loss: 0.1456 - acc: 0.9688 - val_loss: 0.3826 - val_acc: 0.8746
# Epoch 391/500
#  - 0s - loss: 0.1377 - acc: 0.9605 - val_loss: 0.3829 - val_acc: 0.8746
# Epoch 392/500
#  - 0s - loss: 0.1427 - acc: 0.9636 - val_loss: 0.3835 - val_acc: 0.8746
# Epoch 393/500
#  - 0s - loss: 0.1521 - acc: 0.9677 - val_loss: 0.3838 - val_acc: 0.8746
# Epoch 394/500
#  - 0s - loss: 0.1315 - acc: 0.9729 - val_loss: 0.3841 - val_acc: 0.8730
# Epoch 395/500
#  - 0s - loss: 0.1429 - acc: 0.9667 - val_loss: 0.3842 - val_acc: 0.8730
# Epoch 396/500
#  - 0s - loss: 0.1335 - acc: 0.9625 - val_loss: 0.3846 - val_acc: 0.8730
# Epoch 397/500
#  - 0s - loss: 0.1556 - acc: 0.9605 - val_loss: 0.3852 - val_acc: 0.8746
# Epoch 398/500
#  - 0s - loss: 0.1355 - acc: 0.9677 - val_loss: 0.3858 - val_acc: 0.8746
# Epoch 399/500
#  - 0s - loss: 0.1472 - acc: 0.9677 - val_loss: 0.3865 - val_acc: 0.8746
# Epoch 400/500
#  - 0s - loss: 0.1653 - acc: 0.9605 - val_loss: 0.3868 - val_acc: 0.8746
# Epoch 401/500
#  - 0s - loss: 0.1420 - acc: 0.9667 - val_loss: 0.3874 - val_acc: 0.8746
# Epoch 402/500
#  - 0s - loss: 0.1380 - acc: 0.9667 - val_loss: 0.3878 - val_acc: 0.8730
# Epoch 403/500
#  - 0s - loss: 0.1451 - acc: 0.9698 - val_loss: 0.3881 - val_acc: 0.8715
# Epoch 404/500
#  - 0s - loss: 0.1419 - acc: 0.9688 - val_loss: 0.3886 - val_acc: 0.8699
# Epoch 405/500
#  - 0s - loss: 0.1374 - acc: 0.9677 - val_loss: 0.3888 - val_acc: 0.8715
# Epoch 406/500
#  - 0s - loss: 0.1482 - acc: 0.9667 - val_loss: 0.3894 - val_acc: 0.8699
# Epoch 407/500
#  - 0s - loss: 0.1633 - acc: 0.9636 - val_loss: 0.3901 - val_acc: 0.8668
# Epoch 408/500
#  - 0s - loss: 0.1369 - acc: 0.9688 - val_loss: 0.3909 - val_acc: 0.8668
# Epoch 409/500
#  - 0s - loss: 0.1561 - acc: 0.9605 - val_loss: 0.3921 - val_acc: 0.8668
# Epoch 410/500
#  - 0s - loss: 0.1420 - acc: 0.9677 - val_loss: 0.3929 - val_acc: 0.8652
# Epoch 411/500
#  - 0s - loss: 0.1416 - acc: 0.9709 - val_loss: 0.3936 - val_acc: 0.8652
# Epoch 412/500
#  - 0s - loss: 0.1275 - acc: 0.9688 - val_loss: 0.3941 - val_acc: 0.8652
# Epoch 413/500
#  - 0s - loss: 0.1432 - acc: 0.9677 - val_loss: 0.3945 - val_acc: 0.8652
# Epoch 414/500
#  - 0s - loss: 0.1425 - acc: 0.9615 - val_loss: 0.3952 - val_acc: 0.8652
# Epoch 415/500
#  - 0s - loss: 0.1486 - acc: 0.9677 - val_loss: 0.3955 - val_acc: 0.8652
# Epoch 416/500
#  - 0s - loss: 0.1555 - acc: 0.9625 - val_loss: 0.3952 - val_acc: 0.8652
# Epoch 417/500
#  - 0s - loss: 0.1514 - acc: 0.9657 - val_loss: 0.3950 - val_acc: 0.8668
# Epoch 418/500
#  - 0s - loss: 0.1457 - acc: 0.9709 - val_loss: 0.3950 - val_acc: 0.8683
# Epoch 419/500
#  - 0s - loss: 0.1421 - acc: 0.9677 - val_loss: 0.3949 - val_acc: 0.8730
# Epoch 420/500
#  - 0s - loss: 0.1425 - acc: 0.9636 - val_loss: 0.3953 - val_acc: 0.8730
# Epoch 421/500
#  - 0s - loss: 0.1260 - acc: 0.9740 - val_loss: 0.3957 - val_acc: 0.8730
# Epoch 422/500
#  - 0s - loss: 0.1246 - acc: 0.9698 - val_loss: 0.3962 - val_acc: 0.8730
# Epoch 423/500
#  - 0s - loss: 0.1353 - acc: 0.9688 - val_loss: 0.3969 - val_acc: 0.8730
# Epoch 424/500
#  - 0s - loss: 0.1322 - acc: 0.9709 - val_loss: 0.3974 - val_acc: 0.8730
# Epoch 425/500
#  - 0s - loss: 0.1300 - acc: 0.9667 - val_loss: 0.3983 - val_acc: 0.8715
# Epoch 426/500
#  - 0s - loss: 0.1505 - acc: 0.9625 - val_loss: 0.3996 - val_acc: 0.8668
# Epoch 427/500
#  - 0s - loss: 0.1387 - acc: 0.9657 - val_loss: 0.4008 - val_acc: 0.8668
# Epoch 428/500
#  - 0s - loss: 0.1377 - acc: 0.9667 - val_loss: 0.4019 - val_acc: 0.8668
# Epoch 429/500
#  - 0s - loss: 0.1349 - acc: 0.9719 - val_loss: 0.4029 - val_acc: 0.8668
# Epoch 430/500
#  - 0s - loss: 0.1310 - acc: 0.9667 - val_loss: 0.4035 - val_acc: 0.8668
# Epoch 431/500
#  - 0s - loss: 0.1352 - acc: 0.9677 - val_loss: 0.4039 - val_acc: 0.8668
# Epoch 432/500
#  - 0s - loss: 0.1377 - acc: 0.9667 - val_loss: 0.4041 - val_acc: 0.8668
# Epoch 433/500
#  - 0s - loss: 0.1388 - acc: 0.9667 - val_loss: 0.4043 - val_acc: 0.8652
# Epoch 434/500
#  - 0s - loss: 0.1313 - acc: 0.9688 - val_loss: 0.4044 - val_acc: 0.8683
# Epoch 435/500
#  - 0s - loss: 0.1205 - acc: 0.9709 - val_loss: 0.4050 - val_acc: 0.8683
# Epoch 436/500
#  - 0s - loss: 0.1295 - acc: 0.9771 - val_loss: 0.4056 - val_acc: 0.8699
# Epoch 437/500
#  - 0s - loss: 0.1282 - acc: 0.9688 - val_loss: 0.4066 - val_acc: 0.8699
# Epoch 438/500
#  - 0s - loss: 0.1425 - acc: 0.9677 - val_loss: 0.4077 - val_acc: 0.8683
# Epoch 439/500
#  - 0s - loss: 0.1395 - acc: 0.9657 - val_loss: 0.4088 - val_acc: 0.8683
# Epoch 440/500
#  - 0s - loss: 0.1316 - acc: 0.9709 - val_loss: 0.4096 - val_acc: 0.8652
# Epoch 441/500
#  - 0s - loss: 0.1246 - acc: 0.9657 - val_loss: 0.4105 - val_acc: 0.8652
# Epoch 442/500
#  - 0s - loss: 0.1324 - acc: 0.9667 - val_loss: 0.4114 - val_acc: 0.8652
# Epoch 443/500
#  - 0s - loss: 0.1355 - acc: 0.9677 - val_loss: 0.4121 - val_acc: 0.8652
# Epoch 444/500
#  - 0s - loss: 0.1297 - acc: 0.9677 - val_loss: 0.4128 - val_acc: 0.8668
# Epoch 445/500
#  - 0s - loss: 0.1242 - acc: 0.9677 - val_loss: 0.4134 - val_acc: 0.8668
# Epoch 446/500
#  - 0s - loss: 0.1400 - acc: 0.9698 - val_loss: 0.4137 - val_acc: 0.8668
# Epoch 447/500
#  - 0s - loss: 0.1230 - acc: 0.9698 - val_loss: 0.4140 - val_acc: 0.8652
# Epoch 448/500
#  - 0s - loss: 0.1308 - acc: 0.9657 - val_loss: 0.4144 - val_acc: 0.8636
# Epoch 449/500
#  - 0s - loss: 0.1359 - acc: 0.9719 - val_loss: 0.4146 - val_acc: 0.8636
# Epoch 450/500
#  - 0s - loss: 0.1307 - acc: 0.9615 - val_loss: 0.4144 - val_acc: 0.8636
# Epoch 451/500
#  - 0s - loss: 0.1346 - acc: 0.9615 - val_loss: 0.4144 - val_acc: 0.8636
# Epoch 452/500
#  - 0s - loss: 0.1301 - acc: 0.9688 - val_loss: 0.4148 - val_acc: 0.8636
# Epoch 453/500
#  - 0s - loss: 0.1269 - acc: 0.9740 - val_loss: 0.4152 - val_acc: 0.8636
# Epoch 454/500
#  - 0s - loss: 0.1232 - acc: 0.9729 - val_loss: 0.4157 - val_acc: 0.8636
# Epoch 455/500
#  - 0s - loss: 0.1281 - acc: 0.9688 - val_loss: 0.4163 - val_acc: 0.8636
# Epoch 456/500
#  - 0s - loss: 0.1339 - acc: 0.9667 - val_loss: 0.4168 - val_acc: 0.8636
# Epoch 457/500
#  - 0s - loss: 0.1289 - acc: 0.9667 - val_loss: 0.4175 - val_acc: 0.8652
# Epoch 458/500
#  - 0s - loss: 0.1219 - acc: 0.9698 - val_loss: 0.4185 - val_acc: 0.8652
# Epoch 459/500
#  - 0s - loss: 0.1303 - acc: 0.9667 - val_loss: 0.4193 - val_acc: 0.8652
# Epoch 460/500
#  - 0s - loss: 0.1342 - acc: 0.9709 - val_loss: 0.4202 - val_acc: 0.8636
# Epoch 461/500
#  - 0s - loss: 0.1264 - acc: 0.9729 - val_loss: 0.4210 - val_acc: 0.8636
# Epoch 462/500
#  - 0s - loss: 0.1235 - acc: 0.9709 - val_loss: 0.4218 - val_acc: 0.8636
# Epoch 463/500
#  - 0s - loss: 0.1226 - acc: 0.9750 - val_loss: 0.4227 - val_acc: 0.8636
# Epoch 464/500
#  - 0s - loss: 0.1101 - acc: 0.9688 - val_loss: 0.4234 - val_acc: 0.8621
# Epoch 465/500
#  - 0s - loss: 0.1114 - acc: 0.9729 - val_loss: 0.4243 - val_acc: 0.8621
# Epoch 466/500
#  - 0s - loss: 0.1189 - acc: 0.9771 - val_loss: 0.4252 - val_acc: 0.8621
# Epoch 467/500
#  - 0s - loss: 0.1208 - acc: 0.9709 - val_loss: 0.4262 - val_acc: 0.8621
# Epoch 468/500
#  - 0s - loss: 0.1224 - acc: 0.9688 - val_loss: 0.4272 - val_acc: 0.8636
# Epoch 469/500
#  - 0s - loss: 0.1095 - acc: 0.9729 - val_loss: 0.4286 - val_acc: 0.8621
# Epoch 470/500
#  - 0s - loss: 0.1134 - acc: 0.9771 - val_loss: 0.4301 - val_acc: 0.8621
# Epoch 471/500
#  - 0s - loss: 0.1143 - acc: 0.9740 - val_loss: 0.4316 - val_acc: 0.8621
# Epoch 472/500
#  - 0s - loss: 0.1260 - acc: 0.9677 - val_loss: 0.4329 - val_acc: 0.8605
# Epoch 473/500
#  - 0s - loss: 0.1053 - acc: 0.9802 - val_loss: 0.4342 - val_acc: 0.8605
# Epoch 474/500
#  - 0s - loss: 0.1036 - acc: 0.9802 - val_loss: 0.4351 - val_acc: 0.8621
# Epoch 475/500
#  - 0s - loss: 0.1222 - acc: 0.9781 - val_loss: 0.4357 - val_acc: 0.8621
# Epoch 476/500
#  - 0s - loss: 0.1182 - acc: 0.9667 - val_loss: 0.4366 - val_acc: 0.8621
# Epoch 477/500
#  - 0s - loss: 0.1347 - acc: 0.9719 - val_loss: 0.4376 - val_acc: 0.8621
# Epoch 478/500
#  - 0s - loss: 0.1031 - acc: 0.9802 - val_loss: 0.4384 - val_acc: 0.8621
# Epoch 479/500
#  - 0s - loss: 0.1159 - acc: 0.9761 - val_loss: 0.4393 - val_acc: 0.8621
# Epoch 480/500
#  - 0s - loss: 0.1150 - acc: 0.9740 - val_loss: 0.4401 - val_acc: 0.8605
# Epoch 481/500
#  - 0s - loss: 0.1282 - acc: 0.9740 - val_loss: 0.4409 - val_acc: 0.8605
# Epoch 482/500
#  - 0s - loss: 0.1143 - acc: 0.9750 - val_loss: 0.4416 - val_acc: 0.8605
# Epoch 483/500
#  - 0s - loss: 0.1095 - acc: 0.9771 - val_loss: 0.4424 - val_acc: 0.8605
# Epoch 484/500
#  - 0s - loss: 0.1102 - acc: 0.9719 - val_loss: 0.4431 - val_acc: 0.8605
# Epoch 485/500
#  - 0s - loss: 0.1197 - acc: 0.9740 - val_loss: 0.4439 - val_acc: 0.8605
# Epoch 486/500
#  - 0s - loss: 0.1039 - acc: 0.9813 - val_loss: 0.4452 - val_acc: 0.8605
# Epoch 487/500
#  - 0s - loss: 0.1199 - acc: 0.9719 - val_loss: 0.4465 - val_acc: 0.8589
# Epoch 488/500
#  - 0s - loss: 0.1082 - acc: 0.9761 - val_loss: 0.4479 - val_acc: 0.8589
# Epoch 489/500
#  - 0s - loss: 0.1153 - acc: 0.9781 - val_loss: 0.4494 - val_acc: 0.8605
# Epoch 490/500
#  - 0s - loss: 0.1065 - acc: 0.9740 - val_loss: 0.4506 - val_acc: 0.8605
# Epoch 491/500
#  - 0s - loss: 0.0997 - acc: 0.9792 - val_loss: 0.4516 - val_acc: 0.8605
# Epoch 492/500
#  - 0s - loss: 0.1148 - acc: 0.9709 - val_loss: 0.4530 - val_acc: 0.8605
# Epoch 493/500
#  - 0s - loss: 0.1180 - acc: 0.9771 - val_loss: 0.4542 - val_acc: 0.8605
# Epoch 494/500
#  - 0s - loss: 0.1141 - acc: 0.9761 - val_loss: 0.4555 - val_acc: 0.8605
# Epoch 495/500
#  - 0s - loss: 0.1053 - acc: 0.9750 - val_loss: 0.4567 - val_acc: 0.8605
# Epoch 496/500
#  - 0s - loss: 0.1174 - acc: 0.9771 - val_loss: 0.4572 - val_acc: 0.8589
# Epoch 497/500
#  - 0s - loss: 0.1035 - acc: 0.9781 - val_loss: 0.4573 - val_acc: 0.8589
# Epoch 498/500
#  - 0s - loss: 0.1072 - acc: 0.9771 - val_loss: 0.4574 - val_acc: 0.8589
# Epoch 499/500
#  - 0s - loss: 0.1099 - acc: 0.9771 - val_loss: 0.4575 - val_acc: 0.8589
# Epoch 500/500
#  - 0s - loss: 0.1122 - acc: 0.9740 - val_loss: 0.4577 - val_acc: 0.8574
# Baseline Error: 14.26%
# CPU times: user 11.2 s, sys: 989 ms, total: 12.1 s
# Wall time: 11 s

# %%
y_hat = model.predict_proba(X_test_scale)

predictions = pd.DataFrame(y_hat)

predictions['Actual'] = y_test.NCAA.values
predictions['Season'] = y_test.season.values
predictions['Team'] = y_test.team_id.values

predictions.sort_values(by = 0, ascending = False, inplace = True)

#print(predictions.head(75))

pred_2016 = predictions[predictions['Season'] == 2016]
pred_2017 = predictions[predictions['Season'] == 2017]

in_2016 = pred_2016.head(36)
in_2017 = pred_2017.head(36)

print("2016 Top 36 at-large bids correct: ", in_2016.Actual.sum())
print("2017 Top 36 at-large bids correct: ", in_2017.Actual.sum())
# Out:
# 2016 Top 36 at-large bids correct:  33
# 2017 Top 36 at-large bids correct:  29

# %%
from sklearn.linear_model import LogisticRegression
import time


#descriptions of solvers https://stackoverflow.com/questions/38640109/logistic-regression-python-solvers-defintions
# MODEL - BUILD BASE MODEL FOR LOGISTIC REGRESSION

start = time.time()  # TRACK TIME

#X_combined_std = np.vstack((X_train_std, X_test_std))
#y_combined = np.hstack((y_train,y_test))

lr = LogisticRegression(random_state = 1, 
                          solver = "newton-cg", 
                          multi_class='multinomial'
                         )  
  # USING THE LIMITED MEMORY BROYDEN FLETCHER GOLDFARB SHANNO ALGORITHM - MORE INFO HERE - http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

lr.fit(X_train, y_train.NCAA)

  #plot_decision_regions(X=X_combined_std, y=y_combined, classifier=lr,
  #                      test_idx=range(105,150))
  #plt.show()

score = lr.score(X_test, y_test.NCAA)  # ACCURACY AGAINST THE TEST SET
print(score)

end = time.time()
final_time = end-start
print(final_time)  # RUN TIME OF BLOCK
  
  
predictions = pd.DataFrame(lr.predict_proba(X_test))

predictions['Actual'] = y_test.NCAA.values
predictions['Season'] = y_test.season.values
predictions.sort_values(by = 1, ascending = False, inplace = True)

pred_2016 = predictions[predictions['Season'] == 2016]
pred_2017 = predictions[predictions['Season'] == 2017]

in_2016 = pred_2016.head(36)
in_2017 = pred_2017.head(36)

print("2016 Top 36 at-large bid accuracy: ", in_2016.Actual.sum())
print("2017 Top 36 at-large bid accuracy: ", in_2017.Actual.sum())
# Out:
# 0.8605015673981191
# 0.645634651184082
# 2016 Top 36 at-large bid accuracy:  34
# 2017 Top 36 at-large bid accuracy:  31
